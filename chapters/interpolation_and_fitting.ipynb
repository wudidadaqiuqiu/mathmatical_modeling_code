# %% [markdown]
# # 插值与拟合

# %%
from rich import print  # print出来更好看
import sys, os
sys.path.append(os.path.abspath('..'))
# print(sys.path)
from data.basicdata import BasicData
from data.testdata import TestData
from data.univariate import SingleV
import math

# %% [markdown]
# **首先生成待插值的数据**

# %%
x, y = TestData.create_data(math.sin, 0, 6, 8)
BasicData.plot(x, [y])

# %%
# 或者，不连成线，'.','-'...
BasicData.plot(x, [y], '.')
